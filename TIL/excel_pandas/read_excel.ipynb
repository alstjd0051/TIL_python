# %%
import pandas as pd
from pathlib import Path
from icecream import ic

# %% [markdown]
# # Pandas read_excel
#
# > 엑셀 파일을 데이터 프레임으로 불러오는 함수

# %%
data_path = Path("assets") / "02_01_read_excel.xlsx"

# %%
df = pd.read_excel(data_path,sheet_name=3,index_col=0)
ic(df)
# Out:
# ic| df:      국어  영어  수학
#         송중기  63  93  97
#         김나현  89  83  71
#         권보아  83  76  92
#         박효신  94  88  73
#      국어  영어  수학
# 송중기  63  93  97
# 김나현  89  83  71
# 권보아  83  76  92
# 박효신  94  88  73
