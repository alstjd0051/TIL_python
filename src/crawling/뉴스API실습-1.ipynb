# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.parse import quote
import os
from dotenv import load_dotenv

# .env 파일 로드 (노트북 위치에서 상대 경로: ../../.env)
load_dotenv('../../.env')

start = "2026-01-03"
keyword = "업스테이지"
apikey = os.getenv("NEWS_API_KEY")

# 키워드 인코딩
encoded_keyword = quote(keyword)

url_popular = f"https://newsapi.org/v2/everything?q={encoded_keyword}&from={start}&sortBy=popularity&apiKey={apikey}"

print(url_popular)
# Out:
# https://newsapi.org/v2/everything?q=%EC%97%85%EC%8A%A4%ED%85%8C%EC%9D%B4%EC%A7%80&from=2026-01-03&sortBy=popularity&apiKey=fef66a27b126498a8799621055822362

# %%
html = urlopen(url_popular)
bs_obj = BeautifulSoup(html, "html.parser")

# %%
article_dic = json.loads(bs_obj.text)
print(article_dic)
# Out:
# {'status': 'ok', 'totalResults': 5, 'articles': [{'source': {'id': None, 'name': 'Venturesquare.net'}, 'author': '명승은', 'title': '업스테이지 ‘AI 표절 논란’ 종결…신속한 K-AI 생태계 검증 ‘눈길’', 'description': "업스테이지의 LLM 모델이 중국 모델을 표절했다는 의혹이 제기됐으나, 문제 제기 당사자인 사이오닉에이아이 대표의 사과로 일단락됐다. 이번 논란은 단순 파라미터 유사도만으로는 AI 모델의 독창성을 판단하기 어렵다는 기술적 한계를 드러냈다. 동시에 정부 주도 '독파모' 사업의 투명성 확보와 과학적 검증 체계 마련의 필요성을 환기시켰다. 업계는 이번 사태를 계기로 소모적 논쟁 대신 신뢰할 수 있는 기술 검증 표준과 성숙한 경쟁 문화가 정착되어야 한다고 입을 모은다.", 'url': 'https://www.venturesquare.net/1030519', 'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2026/01/1354313.jpg', 'publishedAt': '2026-01-04T05:58:21Z', 'content': '(AI) ‘ ’ .\r\n , AI ‘ ’ . ‘ AI ’ . ‘ AI’ .\r\n 1 1, SNS (LLM) ‘ 100B’ (Zhipu) AI . (LayerNorm) 96.8% . “ ” .\r\n . “ ” , . . 2, “ ” , .\r\n , ?AI ‘ ’ . LLM , . AI ‘ ’ . , ‘ ’ .\r\n“ . , .” ( )\r\n“ . .” ( )\r\n , … [+11080 chars]'}, {'source': {'id': None, 'name': 'Venturesquare.net'}, 'author': '명승은', 'title': '업스테이지 ‘AI 표절 논란’ 종결…신속한 K-AI 생태계 검증 ‘눈길’', 'description': "업스테이지의 LLM 모델이 중국 모델을 표절했다는 의혹이 제기됐으나, 문제 제기 당사자인 사이오닉에이아이 대표의 사과로 일단락됐다. 이번 논란은 단순 파라미터 유사도만으로는 AI 모델의 독창성을 판단하기 어렵다는 기술적 한계를 드러냈다. 동시에 정부 주도 '독파모' 사업의 투명성 확보와 과학적 검증 체계 마련의 필요성을 환기시켰다. 업계는 이번 사태를 계기로 소모적 논쟁 대신 신뢰할 수 있는 기술 검증 표준과 성숙한 경쟁 문화가 정착되어야 한다고 입을 모은다.", 'url': 'https://www.venturesquare.net/1030519/', 'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2026/01/1354313.jpg', 'publishedAt': '2026-01-04T05:58:21Z', 'content': '(AI) ‘ ’ .\r\n , AI ‘ ’ . ‘ AI ’ . ‘ AI’ .\r\n 1 1, SNS (LLM) ‘ 100B’ (Zhipu) AI . (LayerNorm) 96.8% . “ ” .\r\n . “ ” , . . 2, “ ” , .\r\n , ?AI ‘ ’ . LLM , . AI ‘ ’ . , ‘ ’ .\r\n“ . , .” ( )\r\n“ . .” ( )\r\n , … [+11080 chars]'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '장유미 기자', 'title': "[유미's 픽] 고석현發 中 모델 의혹에 정부도 '움찔'…국가대표 AI 개발 경로까지 본다", 'description': "[지디넷코리아]정부가 독자 인공지능(AI) 파운데이션 모델 프로젝트 정예 5개 팀을 대상으로 최종 모델뿐 아니라 복수의 중간 학습 기록까지 제출받아 검증하기로 하면서 국가 AI 사업의 평가 기준이 성능 경쟁에서 개발 경로 검증 중심으로 전환되고 있다. 업스테이지의 '솔라 오픈 100B'를 둘러싼 모델 유사성 논란을 계기로, 정부가 '프롬 스크래치(from scratch)' 여부를 기술적으로 입증하는 체계를 본격화했다는 해석이 나온다.4일 과학기술정보통신부에 따…", 'url': 'https://zdnet.co.kr/view/?no=20260104005942', 'urlToImage': 'https://image.zdnet.co.kr/2025/12/30/1b6a341d4f0380a951e2b78039092716.jpg', 'publishedAt': '2026-01-03T21:00:05Z', 'content': '(AI) 5 AI . \' 100B\' , \' (from scratch)\' .\r\n4 15\xa0 AI 5 . (checkpoint) (TTA) .\r\n AI . .\r\n" " " AI " .\r\n (=)\r\n1 AI \xa0\' 100B\' AI · . \' 100B\' AI \'GLM-4.5-\' . AI ( ) .\r\n\xa0 .\xa0\r\n " , " " " .\xa0\r\n \xa0 " " " AI " .\r… [+279 chars]'}, {'source': {'id': None, 'name': 'Inews24.com'}, 'author': '윤소진', 'title': '업스테이지, 中 AI 카피 의혹 일단락…남은 건 정부의 판단 [AI브리핑]', 'description': "2000명 이상 실시간으로 지켜본 '역사적 검증회'\r\n전문가들, 업스테이지 지지…15일 정부평가에 이목 연초부터 업스테이지와 사이오닉AI 간 ‘중국 모델 파생’ 공방이 업계를 뜨겁게 달궜지만, 업스테이지의 정면 돌파로 논란은 사실상 일단락된 분위기다. 문제 제기를 주도했던 사이오닉AI 측이 관련 리포트를 삭제하고 공개 검증 현장에도 모습을 드러내지 않으면서 논쟁의 무게추는 기술 진위 공방에서 제도·정책 판단의 영역…", 'url': 'https://www.inews24.com/view/1924011', 'urlToImage': 'https://image.inews24.com/v1/9124b7c1bf2c1f.jpg', 'publishedAt': '2026-01-04T02:09:03Z', 'content': '[24 ] AI , . AI · .\r\n . [=]\r\n" " \r\n4 2 AI . .\r\n 1 AI 100B (Zhipu) AI GLM . AI .\r\n LayerNorm . LayerNorm AI , 1 . , .\r\n2 . 100B . .\r\n " , " " " .\r\n . LayerNorm 1 1 , .\r\n AI . · AI AI . , , .\r\n AI . . … [+101 chars]'}, {'source': {'id': None, 'name': 'Inews24.com'}, 'author': '서효빈', 'title': "KT '믿:음 K', 글로벌 AI 평가서 국내 중소형 모델 1위", 'description': "에이전트 성능 최정상 수준… 한국 기업 위한 ‘에이전틱 AI’ 솔루션 제시 KT는 자체 개발한 인공지능(AI) 모델 '믿:음 K'가 글로벌 AI 모델 성능 종합 평가 플랫폼 'AAII'에서 국내 중소형 모델 가운데 1위를 차지했다고 5일 밝혔다. AAII는 AI 평가 전문 기관 Artificial Analysis가 운영하는 글로벌 평가 플랫폼이다. 단일 시험이 아닌 다수의 공개 벤치마크 결과를 종합해 전 세계 주요 AI 모델 …", 'url': 'https://www.inews24.com/view/1924215', 'urlToImage': 'https://image.inews24.com/v1/144ce70f0f1f68.jpg', 'publishedAt': '2026-01-05T01:32:25Z', 'content': "[24 ] KT (AI) ': K' AI 'AAII' 1 5 .\r\nAAII(Artificial Analysis Intelligence Index) : K [=AAII]\r\nAAII AI Artificial Analysis . AI  ...

# %%
type(article_dic)
# Out:
# dict

# %%
article_dic['articles']
# Out:
# [{'source': {'id': None, 'name': 'Venturesquare.net'},
#   'author': '명승은',
#   'title': '업스테이지 ‘AI 표절 논란’ 종결…신속한 K-AI 생태계 검증 ‘눈길’',
#   'description': "업스테이지의 LLM 모델이 중국 모델을 표절했다는 의혹이 제기됐으나, 문제 제기 당사자인 사이오닉에이아이 대표의 사과로 일단락됐다. 이번 논란은 단순 파라미터 유사도만으로는 AI 모델의 독창성을 판단하기 어렵다는 기술적 한계를 드러냈다. 동시에 정부 주도 '독파모' 사업의 투명성 확보와 과학적 검증 체계 마련의 필요성을 환기시켰다. 업계는 이번 사태를 계기로 소모적 논쟁 대신 신뢰할 수 있는 기술 검증 표준과 성숙한 경쟁 문화가 정착되어야 한다고 입을 모은다.",
#   'url': 'https://www.venturesquare.net/1030519',
#   'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2026/01/1354313.jpg',
#   'publishedAt': '2026-01-04T05:58:21Z',
#   'content': '(AI) ‘ ’ .\r\n , AI ‘ ’ . ‘ AI ’ . ‘ AI’ .\r\n 1 1, SNS (LLM) ‘ 100B’ (Zhipu) AI . (LayerNorm) 96.8% . “ ” .\r\n . “ ” , . . 2, “ ” , .\r\n , ?AI ‘ ’ . LLM , . AI ‘ ’ . , ‘ ’ .\r\n“ . , .” ( )\r\n“ . .” ( )\r\n , … [+11080 chars]'},
#  {'source': {'id': None, 'name': 'Venturesquare.net'},
#   'author': '명승은',
#   'title': '업스테이지 ‘AI 표절 논란’ 종결…신속한 K-AI 생태계 검증 ‘눈길’',
#   'description': "업스테이지의 LLM 모델이 중국 모델을 표절했다는 의혹이 제기됐으나, 문제 제기 당사자인 사이오닉에이아이 대표의 사과로 일단락됐다. 이번 논란은 단순 파라미터 유사도만으로는 AI 모델의 독창성을 판단하기 어렵다는 기술적 한계를 드러냈다. 동시에 정부 주도 '독파모' 사업의 투명성 확보와 과학적 검증 체계 마련의 필요성을 환기시켰다. 업계는 이번 사태를 계기로 소모적 논쟁 대신 신뢰할 수 있는 기술 검증 표준과 성숙한 경쟁 문화가 정착되어야 한다고 입을 모은다.",
#   'url': 'https://www.venturesquare.net/1030519/',
#   'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2026/01/1354313.jpg',
#   'publishedAt': '2026-01-04T05:58:21Z',
#   'content': '(AI) ‘ ’ .\r\n , AI ‘ ’ . ‘ AI ’ . ‘ AI’ .\r\n 1 1, SNS (LLM) ‘ 100B’ (Zhipu) AI . (LayerNorm) 96.8% . “ ” .\r\n . “ ” , . . 2, “ ” , .\r\n , ?AI ‘ ’ . LLM , . AI ‘ ’ . , ‘ ’ .\r\n“ . , .” ( )\r\n“ . .” ( )\r\n , … [+11080 chars]'},
#  {'source': {'id': None, 'name': 'Zdnet.co.kr'},
#   'author': '장유미 기자',
#   'title': "[유미's 픽] 고석현發 中 모델 의혹에 정부도 '움찔'…국가대표 AI 개발 경로까지 본다",
#   'description': "[지디넷코리아]정부가 독자 인공지능(AI) 파운데이션 모델 프로젝트 정예 5개 팀을 대상으로 최종 모델뿐 아니라 복수의 중간 학습 기록까지 제출받아 검증하기로 하면서 국가 AI 사업의 평가 기준이 성능 경쟁에서 개발 경로 검증 중심으로 전환되고 있다. 업스테이지의 '솔라 오픈 100B'를 둘러싼 모델 유사성 논란을 계기로, 정부가 '프롬 스크래치(from scratch)' 여부를 기술적으로 입증하는 체계를 본격화했다는 해석이 나온다.4일 과학기술정보통신부에 따…",
#   'url': 'https://zdnet.co.kr/view/?no=20260104005942',
#   'urlToImage': 'https://image.zdnet.co.kr/2025/12/30/1b6a341d4f0380a951e2b78039092716.jpg',
#   'publishedAt': '2026-01-03T21:00:05Z',
#   'content': '(AI) 5 AI . \' 100B\' , \' (from scratch)\' .\r\n4 15\xa0 AI 5 . (checkpoint) (TTA) .\r\n AI . .\r\n" " " AI " .\r\n (=)\r\n1 AI \xa0\' 100B\' AI · . \' 100B\' AI \'GLM-4.5-\' . AI ( ) .\r\n\xa0 .\xa0\r\n " , " " " .\xa0\r\n \xa0 " " " AI " .\r… [+279 chars]'},
#  {'source': {'id': None, 'name': 'Inews24.com'},
#   'author': '윤소진',
#   'title': '업스테이지, 中 AI 카피 의혹 일단락…남은 건 정부의 판단 [AI브리핑]',
#   'description': "2000명 이상 실시간으로 지켜본 '역사적 검증회'\r\n전문가들, 업스테이지 지지…15일 정부평가에 이목 연초부터 업스테이지와 사이오닉AI 간 ‘중국 모델 파생’ 공방이 업계를 뜨겁게 달궜지만, 업스테이지의 정면 돌파로 논란은 사실상 일단락된 분위기다. 문제 제기를 주도했던 사이오닉AI 측이 관련 리포트를 삭제하고 공개 검증 현장에도 모습을 드러내지 않으면서 논쟁의 무게추는 기술 진위 공방에서 제도·정책 판단의 영역…",
#   'url': 'https://www.inews24.com/view/1924011',
#   'urlToImage': 'https://image.inews24.com/v1/9124b7c1bf2c1f.jpg',
#   'publishedAt': '2026-01-04T02:09:03Z',
#   'content': '[24 ] AI , . AI · .\r\n . [=]\r\n" " \r\n4 2 AI . .\r\n 1 AI 100B (Zhipu) AI GLM . AI .\r\n LayerNorm . LayerNorm AI , 1 . , .\r\n2 . 100B . .\r\n " , " " " .\r\n . LayerNorm 1 1 , .\r\n AI . · AI AI . , , .\r\n AI . . … [+101 chars]'},
#  {'source': {'id': None, 'name': 'Inews24.com'},
#   'author': '서효빈',
#   'title': "KT '믿:음 K', 글로벌 AI 평가서 국내 중소형 모델 1위",
#   'description': "에이전트 성능 최정상 수준… 한국 기업 위한 ‘에이전틱 AI’ 솔루션 제시 KT는 자체 개발한 인공지능(AI) 모델 '믿:음 K'가 글로벌 AI 모델 성능 종합 평가 플랫폼 'AAII'에서 국내 중소형 모델 가운데 1위를 차지했다고 5일 밝혔다. AAII는 AI 평가 전문 기관 Artificial Analysis가 운영하는 글로벌 평가 플랫폼이다. 단일 시험이 아닌 다수의 공개 벤치마크 결과를 종합해 전 세계 주요 AI 모델 …",
#   'url': 'https://www.inews24.com/view/1924215',
#   'urlToImage': 'https://image.inews24.com/v1/144ce70f0f1f68.jpg',
#   'publishedAt': '2026-01-05T01:32:25Z',
#   'content': "[24 ] KT (AI) ': K' AI 'AAII' 1 5 .\r\nAAII(Artificial Analysis Intelligence Index) : K [=AAII]\r\nAAII AI Artificial Analysis . AI . AI LG , , , .\r\n ': K' , , ·, 10 . AI .\r\n KT ': K' '²-bench( )' 87% . … [+94 chars]"}]

# %%
article_dic['articles'][0]['content']
# Out:
# '(AI) ‘ ’ .\r\n , AI ‘ ’ . ‘ AI ’ . ‘ AI’ .\r\n 1 1, SNS (LLM) ‘ 100B’ (Zhipu) AI . (LayerNorm) 96.8% . “ ” .\r\n . “ ” , . . 2, “ ” , .\r\n , ?AI ‘ ’ . LLM , . AI ‘ ’ . , ‘ ’ .\r\n“ . , .” ( )\r\n“ . .” ( )\r\n , … [+11080 chars]'

# %%
n = len(article_dic['articles'])
n
# Out:
# 5

# %%
keywords = ["AI", "china"]
a = article_dic['articles']
count = 0
for i in range(n):
    content = article_dic['articles'][i].get('content', '')
    for keyword in keywords:
        count += content.count(keyword)
print(count)
# Out:
# 45
