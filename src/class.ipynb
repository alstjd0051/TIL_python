# %%
class Country01:
    name= "국가명"
    captial = "수도"
    population = 100

    def introduce(self):
        sentence = '국가 소개 문장입니다.'
        return sentence

# %%
ex1 = Country01()

# %%
ex1.name
# Out:
# '국가명'

# %%
import os
print(os.getcwd())
# Out:
# /Users/tylersong/Desktop/workspace/learn/python/src
